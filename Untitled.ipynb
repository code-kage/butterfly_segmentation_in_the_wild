# %%
from PIL import Image, ImageDraw

# %%
images = []

for i in range(50):
    images.append(Image.open(f"doc/epochs/{i}.jpg"))

# %%
images[0].save('doc/conv_epochs.gif',save_all=True, append_images=images[1:], optimize=True, duration=80,loop=True)
